# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# **Titanic Dataset EDA**

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly.express as px

# %%
df = pd.read_csv("Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.columns.to_list()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df[df["Age"].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 5      male  NaN      0      0      330877   8.4583   NaN        Q
# 17     male  NaN      0      0      244373  13.0000   NaN        S
# 19   female  NaN      0      0        2649   7.2250   NaN        C
# 26     male  NaN      0      0        2631   7.2250   NaN        C
# 28   female  NaN      0      0      330959   7.8792   NaN        Q
# ..      ...  ...    ...    ...         ...      ...   ...      ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S
# 868    male  NaN      0      0      345777   9.5000   NaN        S
# 878    male  NaN      0      0      349217   7.8958   NaN        S
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S
#
# [177 rows x 12 columns]

# %%
df[df["Age"].isna() & (df["Pclass"] == 3)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# 29            30         0       3                       Todoroff, Mr. Lalio
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 5      male  NaN      0      0      330877   8.4583   NaN        Q
# 19   female  NaN      0      0        2649   7.2250   NaN        C
# 26     male  NaN      0      0        2631   7.2250   NaN        C
# 28   female  NaN      0      0      330959   7.8792   NaN        Q
# 29     male  NaN      0      0      349216   7.8958   NaN        S
# ..      ...  ...    ...    ...         ...      ...   ...      ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S
# 868    male  NaN      0      0      345777   9.5000   NaN        S
# 878    male  NaN      0      0      349217   7.8958   NaN        S
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S
#
# [136 rows x 12 columns]

# %%
x = df["Age"] [(df["Pclass"] == 1) & (df['Sex'] == 'male')].mean()
y = df["Age"] [(df["Pclass"] == 1) & (df['Sex'] == 'female')].mean()
print(x)
print(y)
# Out:
# 41.28138613861386
# 34.61176470588235

# %%
df.loc[(df["Age"].isna()) & (df["Pclass"] == 3) & (df["Sex"] == "male"), "Age"] = x 
# Fill missing Age values for males in 3rd class with x
df.loc[(df["Age"].isna()) & (df["Pclass"] == 3) & (df["Sex"] == "female"), "Age"] = y 
# Fill missing Age values for females in 3rd class with y
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             41
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
a = df["Age"][(df["Pclass"] == 1) & (df['Sex'] == 'male')].mean()
b = df["Age"][(df["Pclass"] == 1) & (df['Sex'] == 'female')].mean()
c = df["Age"][(df["Pclass"] == 2) & (df['Sex'] == 'male')].mean()
d = df["Age"][(df["Pclass"] == 2) & (df['Sex'] == 'female')].mean()
print(a , b , c , d  , sep= "\n")
# Out:
# 41.28138613861386
# 34.61176470588235
# 30.74070707070707
# 28.722972972972972

# %%
df.loc[(df["Age"].isna()) & (df["Pclass"] == 1) & (df["Sex"] == "male"), "Age"] = a # Fill missing Age values for males in 1st class with a
df.loc[(df["Age"].isna()) & (df["Pclass"] == 1) & (df["Sex"] == "female"), "Age"] = b # Fill missing Age values for females in 1st class with b
df.loc[(df["Age"].isna()) & (df["Pclass"] == 2) & (df["Sex"] == "male"), "Age"] = c # Fill missing Age values for males in 2nd class with c
df.loc[(df["Age"].isna()) & (df["Pclass"] == 2) & (df["Sex"] == "female"), "Age"] = d # Fill missing Age values for females in 2nd class with d
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df[df["Cabin"].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.000000      1      0         A/5 21171   7.2500   NaN        S
# 2    female  26.000000      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      male  35.000000      0      0            373450   8.0500   NaN        S
# 5      male  41.281386      0      0            330877   8.4583   NaN        Q
# 7      male   2.000000      3      1            349909  21.0750   NaN        S
# ..      ...        ...    ...    ...               ...      ...   ...      ...
# 884    male  25.000000      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.000000      0      5            382652  29.1250   NaN        Q
# 886    male  27.000000      0      0            211536  13.0000   NaN        S
# 888  female  34.611765      1      2        W./C. 6607  23.4500   NaN        S
# 890    male  32.000000      0      0            370376   7.7500   NaN        Q
#
# [687 rows x 12 columns]

# %%
df["Cabin"] = df["Cabin"].fillna("HasNoCabin")
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
# Create a new column 'HasCabin': 1 if the passenger has a cabin, 0 if not
def HasCabin(cell):
    if cell == "HasNoCabin":
        return 0  # No cabin
    return 1      # Has a cabin

df["HasCabin"] = df["Cabin"].apply(HasCabin)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  34.611765
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare       Cabin Embarked  HasCabin
# 0        1      0         A/5 21171   7.2500  HasNoCabin        S         0
# 1        1      0          PC 17599  71.2833         C85        C         1
# 2        0      0  STON/O2. 3101282   7.9250  HasNoCabin        S         0
# 3        1      0            113803  53.1000        C123        S         1
# 4        0      0            373450   8.0500  HasNoCabin        S         0
# ..     ...    ...               ...      ...         ...      ...       ...
# 886      0      0            211536  13.0000  HasNoCabin        S         0
# 887      0      0            112053  30.0000         B42        S         1
# 888      1      2        W./C. 6607  23.4500  HasNoCabin        S         0
# 889      0      0            111369  30.0000        C148        C         1
# 890      0      0            370376   7.7500  HasNoCabin        Q         0
#
# [891 rows x 13 columns]

# %%
df[df["Embarked"].isna()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked  HasCabin
# 61   female  38.0      0      0  113572  80.0   B28      NaN         1
# 829  female  62.0      0      0  113572  80.0   B28      NaN         1

# %%
# Fill missing values in the 'Embarked' column with 'C' (Cherbourg)
df["Embarked"].fillna("C" , inplace= True)
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# HasCabin       0
# dtype: int64

# %%
df.describe() # Age , Fare ?
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   31.483549    0.523008
# std     257.353842    0.486592    0.836071   13.586558    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   32.000000    0.000000
# 75%     668.500000    1.000000    3.000000   41.281386    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare    HasCabin
# count  891.000000  891.000000  891.000000
# mean     0.381594   32.204208    0.228956
# std      0.806057   49.693429    0.420397
# min      0.000000    0.000000    0.000000
# 25%      0.000000    7.910400    0.000000
# 50%      0.000000   14.454200    0.000000
# 75%      0.000000   31.000000    0.000000
# max      6.000000  512.329200    1.000000

# %%
df[df["Age"] == df["Age"].max()]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked  HasCabin
# 630  male  80.0      0      0  27042  30.0   A23        S         1

# %%
df[df["Age"] == df["Age"].min()]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander  male
#
#       Age  SibSp  Parch Ticket    Fare       Cabin Embarked  HasCabin
# 803  0.42      0      1   2625  8.5167  HasNoCabin        C         0

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(10,6))
plt.title("Age Distribution" , fontsize = 16)
sns.histplot(df , x="Age" , kde=True)
# Out:
# <Axes: title={'center': 'Age Distribution'}, xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
plt.title("Age By Class" , fontsize = 16)
sns.boxplot(x='Pclass', y='Age', data=df , hue= "Pclass" , palette= "plasma")
# Out:
# <Axes: title={'center': 'Age By Class'}, xlabel='Pclass', ylabel='Age'>

# %%
Q3 , Q1 = 36.000000 , 21.750000
IQR = Q3 - Q1
UB = Q3 + 1.5 * IQR
UB
# Out:
# 57.375

# %%
outliers_Age = df[df["Age"] > UB]
outliers_Age
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 33            34         0       2
# 54            55         0       1
# 94            95         0       3
# 96            97         0       1
# 116          117         0       3
# 170          171         0       1
# 195          196         1       1
# 232          233         0       2
# 252          253         0       1
# 268          269         1       1
# 275          276         1       1
# 280          281         0       3
# 326          327         0       3
# 366          367         1       1
# 438          439         0       1
# 456          457         0       1
# 483          484         1       3
# 487          488         0       1
# 493          494         0       1
# 545          546         0       1
# 555          556         0       1
# 570          571         1       2
# 587          588         1       1
# 625          626         0       1
# 630          631         1       1
# 659          660         0       1
# 672          673         0       2
# 684          685         0       2
# 694          695         0       1
# 745          746         0       1
# 829          830         1       1
# 851          852         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 33                              Wheadon, Mr. Edward H    male  66.0      0
# 54                     Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 94                                  Coxon, Mr. Daniel    male  59.0      0
# 96                          Goldschmidt, Mr. George B    male  71.0      0
# 116                              Connors, Mr. Patrick    male  70.5      0
# 170                         Van der hoef, Mr. Wyckoff    male  61.0      0
# 195                              Lurette, Miss. Elise  female  58.0      0
# 232                         Sjostedt, Mr. Ernst Adolf    male  59.0      0
# 252                         Stead, Mr. William Thomas    male  62.0      0
# 268     Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
# 275                 Andrews, Miss. Kornelia Theodosia  female  63.0      1
# 280                                  Duane, Mr. Frank    male  65.0      0
# 326                         Nysveen, Mr. Johan Hansen    male  61.0      0
# 366  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 438                                 Fortune, Mr. Mark    male  64.0      1
# 456                         Millet, Mr. Francis Davis    male  65.0      0
# 483                            Turkula, Mrs. (Hedwig)  female  63.0      0
# 487                           Kent, Mr. Edward Austin    male  58.0      0
# 493                           Artagaveytia, Mr. Ramon    male  71.0      0
# 545                      Nicholson, Mr. Arthur Ernest    male  64.0      0
# 555                                Wright, Mr. George    male  62.0      0
# 570                                Harris, Mr. George    male  62.0      0
# 587                  Frolicher-Stehli, Mr. Maxmillian    male  60.0      1
# 625                             Sutton, Mr. Frederick    male  61.0      0
# 630              Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# 659                        Newell, Mr. Arthur Webster    male  58.0      0
# 672                       Mitchell, Mr. Henry Michael    male  70.0      0
# 684                 Brown, Mr. Thomas William Solomon    male  60.0      1
# 694                                   Weir, Col. John    male  60.0      0
# 745                      Crosby, Capt. Edward Gifford    male  70.0      1
# 829         Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
# 851                               Svensson, Mr. Johan    male  74.0      0
#
#      Parch       Ticket      Fare        Cabin Embarked  HasCabin
# 11       0       113783   26.5500         C103        S         1
# 33       0   C.A. 24579   10.5000   HasNoCabin        S         0
# 54       1       113509   61.9792          B30        C         1
# 94       0       364500    7.2500   HasNoCabin        S         0
# 96       0     PC 17754   34.6542           A5        C         1
# 116      0       370369    7.7500   HasNoCabin        Q         0
# 170      0       111240   33.5000          B19        S         1
# 195      0     PC 17569  146.5208          B80        C         1
# 232      0       237442   13.5000   HasNoCabin        S         0
# 252      0       113514   26.5500          C87        S         1
# 268      1     PC 17582  153.4625         C125        S         1
# 275      0        13502   77.9583           D7        S         1
# 280      0       336439    7.7500   HasNoCabin        Q         0
# 326      0       345364    6.2375   HasNoCabin        S         0
# 366      0       110813   75.2500          D37        C         1
# 438      4        19950  263.0000  C23 C25 C27        S         1
# 456      0        13509   26.5500          E38        S         1
# 483      0         4134    9.5875   HasNoCabin        S         0
# 487      0        11771   29.7000          B37        C         1
# 493      0     PC 17609   49.5042   HasNoCabin        C         0
# 545      0          693   26.0000   HasNoCabin        S         0
# 555      0       113807   26.5500   HasNoCabin        S         0
# 570      0  S.W./PP 752   10.5000   HasNoCabin        S         0
# 587      1        13567   79.2000          B41        C         1
# 625      0        36963   32.3208          D50        S         1
# 630      0        27042   30.0000          A23        S         1
# 659      2        35273  113.2750          D48        C         1
# 672      0   C.A. 24580   10.5000   HasNoCabin        S         0
# 684      1        29750   39.0000   HasNoCabin        S         0
# 694      0       113800   26.5500   HasNoCabin        S         0
# 745      1    WE/P 5735   71.0000          B22        S         1
# 829      0       113572   80.0000          B28      NaN         1
# 851      0       347060    7.7750   HasNoCabin        S         0

# %%
df[df["SibSp"] == df["SibSp"].max()]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#            Age  SibSp  Parch    Ticket   Fare       Cabin Embarked  HasCabin
# 159  41.281386      8      2  CA. 2343  69.55  HasNoCabin        S         0
# 180  34.611765      8      2  CA. 2343  69.55  HasNoCabin        S         0
# 201  41.281386      8      2  CA. 2343  69.55  HasNoCabin        S         0
# 324  41.281386      8      2  CA. 2343  69.55  HasNoCabin        S         0
# 792  34.611765      8      2  CA. 2343  69.55  HasNoCabin        S         0
# 846  41.281386      8      2  CA. 2343  69.55  HasNoCabin        S         0
# 863  34.611765      8      2  CA. 2343  69.55  HasNoCabin        S         0

# %%
plt.figure(figsize=(10,6))
plt.title("Fare Distribution" , fontsize = 16)
sns.histplot(df , x="Fare" , kde=True)
# Out:
# <Axes: title={'center': 'Fare Distribution'}, xlabel='Fare', ylabel='Count'>

# %%
fig = px.box(df , x = "Sex" , y= "Fare" , color = "Sex" ,title="Fare Distribution by Sex", labels={"Sex": "Gender"})
fig.show()

# %%
df[df["Fare"] == df["Fare"].max()]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292   HasNoCabin        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#      HasCabin
# 258         0
# 679         1
# 737         1

# %%
Q3 , Q1 = 31.000000 , 7.910400
IQR = Q3 - Q1
UB = Q3 + 1.5 * IQR
UB
# Out:
# 65.6344

# %%
df[df["Fare"] > UB]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 27            28         0       1
# 31            32         1       1
# 34            35         0       1
# 52            53         1       1
# ..           ...       ...     ...
# 846          847         0       3
# 849          850         1       1
# 856          857         1       1
# 863          864         0       3
# 879          880         1       1
#
#                                                   Name     Sex        Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 27                      Fortune, Mr. Charles Alexander    male  19.000000
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female  34.611765
# 34                             Meyer, Mr. Edgar Joseph    male  28.000000
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.000000
# ..                                                 ...     ...        ...
# 846                           Sage, Mr. Douglas Bullen    male  41.281386
# 849       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female  34.611765
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.000000
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female  34.611765
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.000000
#
#      SibSp  Parch    Ticket      Fare        Cabin Embarked  HasCabin
# 1        1      0  PC 17599   71.2833          C85        C         1
# 27       3      2     19950  263.0000  C23 C25 C27        S         1
# 31       1      0  PC 17569  146.5208          B78        C         1
# 34       1      0  PC 17604   82.1708   HasNoCabin        C         0
# 52       1      0  PC 17572   76.7292          D33        C         1
# ..     ...    ...       ...       ...          ...      ...       ...
# 846      8      2  CA. 2343   69.5500   HasNoCabin        S         0
# 849      1      0     17453   89.1042          C92        C         1
# 856      1      1     36928  164.8667   HasNoCabin        S         0
# 863      8      2  CA. 2343   69.5500   HasNoCabin        S         0
# 879      0      1     11767   83.1583          C50        C         1
#
# [116 rows x 13 columns]

# %%
pclass_counts = df["Pclass"][df["Fare"] > UB].value_counts()
sns.barplot(x=pclass_counts.index, y=pclass_counts.values, palette="viridis" , hue= pclass_counts.index)
plt.xlabel("Pclass")
plt.ylabel("Count")
plt.title("Number of Passengers with Fare > Upper Bound by Pclass")
plt.show()

# %%
correlation = df.corr(numeric_only=True)
plt.figure(figsize=(10,8))
sns.heatmap(correlation, annot=True, cmap="plasma", linewidths=0.5)
plt.title("Correlation Heatmap of Titanic Dataset (Numeric Features)")
plt.show()

# %%
df.describe(include= "O")
# Out:
#                            Name   Sex  Ticket       Cabin Embarked
# count                       891   891     891         891      889
# unique                      891     2     681         148        3
# top     Braund, Mr. Owen Harris  male  347082  HasNoCabin        S
# freq                          1   577       7         687      644

# %%
pclass_pivot=df.pivot_table(index= "Pclass" , values= "Fare" , aggfunc= ["mean" , "sum"])
pclass_pivot
# Out:
#              mean         sum
#              Fare        Fare
# Pclass
# 1       84.154687  18177.4125
# 2       20.662183   3801.8417
# 3       13.675550   6714.6951

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
pclass_pivot['mean'].plot(kind='bar', ax=axes[0], title='Average Fare by Pclass')
axes[0].set_ylabel('Mean Fare')
pclass_pivot['sum'].plot(kind='bar', ax=axes[1], title='Total Fare by Pclass')
axes[1].set_ylabel('Sum of Fare')
plt.tight_layout()  
plt.show()

# %%
embarked_pivot=df.pivot_table(index= "Embarked" , values= "Fare" , aggfunc= ["mean" , "sum"])
embarked_pivot
# Out:
#                mean         sum
#                Fare        Fare
# Embarked
# C         59.954144  10072.2962
# Q         13.276030   1022.2543
# S         27.079812  17439.3988

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
embarked_pivot['mean'].plot(kind='bar', ax=axes[0], title='Average Fare by Embarked')
axes[0].set_ylabel('Mean Fare')
embarked_pivot['sum'].plot(kind='bar', ax=axes[1], title='Total Fare by Embarked')
axes[1].set_ylabel('Sum of Fare')
plt.tight_layout()  
plt.show()

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))  

# Count of Pclass
sns.countplot(data=df, x='Pclass', ax=axes[0,0] , hue= "Pclass")
axes[0,0].set_title('Passenger Count by Pclass')
axes[0,0].set_xlabel('Pclass')
axes[0,0].set_ylabel('Count')

# Count of Sex
sns.countplot(data=df, x='Sex', hue='Sex', ax=axes[0,1])
axes[0,1].set_title('Passenger Count by Sex')
axes[0,1].set_xlabel('Sex')
axes[0,1].set_ylabel('Count')
axes[0,1].legend(title='Sex')

# Pie chart Embarked
axes[1,0].pie(df['Embarked'].value_counts(),
               labels=df['Embarked'].value_counts().index,
               autopct='%1.1f%%', startangle=90)
axes[1,0].set_title('Passenger Embarked Distribution')

# Pie chart Survived
axes[1,1].pie(df['Survived'].value_counts(),
               labels=['Not Survived','Survived'],
               autopct='%1.1f%%', startangle=90)
axes[1,1].set_title('Survival Distribution')

plt.suptitle('Titanic Passenger Data Overview', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])  
plt.show()

# %%
sns.countplot(data=df,x='Survived',hue='Sex')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=df, x='Pclass', hue='Survived', multiple='fill')
plt.title('Survival Rate by Pclass')
plt.ylabel('Proportion')
plt.xlabel('Pclass')
plt.legend(title='Survived', labels=['Not Survived','Survived'])
plt.show()
