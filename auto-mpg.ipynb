# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# Check what files are in the current directory
import os
print(os.listdir('.'))
# Out:
# ['auto-mpg.csv', '.git', '.vscode', 'auto-mpg.ipynb', 'titanic.ipynb', 'Titanic-Dataset.csv', 'README.md', 'LICENSE']

# %%
data = pd.read_csv('auto-mpg.csv', index_col='car name')

# %%
print(data.head())
print(data.index)
print(data.columns)
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# car name
# chevrolet chevelle malibu  18.0          8         307.0        130    3504
# buick skylark 320          15.0          8         350.0        165    3693
# plymouth satellite         18.0          8         318.0        150    3436
# amc rebel sst              16.0          8         304.0        150    3433
# ford torino                17.0          8         302.0        140    3449
#
#                            acceleration  model year  origin
# car name
# chevrolet chevelle malibu          12.0          70       1
# buick skylark 320                  11.5          70       1
# plymouth satellite                 11.0          70       1
# amc rebel sst                      12.0          70       1
# ford torino                        10.5          70       1
# Index(['chevrolet chevelle malibu', 'buick skylark 320', 'plymouth satellite',
#        'amc rebel sst', 'ford torino', 'ford galaxie 500', 'chevrolet impala',
#        'plymouth fury iii', 'pontiac catalina', 'amc ambassador dpl',
#        ...
#        'chrysler lebaron medallion', 'ford granada l', 'toyota celica gt',
#        'dodge charger 2.2', 'chevrolet camaro', 'ford mustang gl', 'vw pickup',
#        'dodge rampage', 'ford ranger', 'chevy s-10'],
#       dtype='str', name='car name', length=398)
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin'],
#       dtype='str')

# %%
data.shape
# Out:
# (398, 8)

# %%
data.isnull().any()
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower      False
# weight          False
# acceleration    False
# model year      False
# origin          False
# dtype: bool

# %%
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower          str
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# dtype: object

# %%
data.horsepower.unique()
# Out:
# <StringArray>
# ['130', '165', '150', '140', '198', '220', '215', '225', '190', '170', '160',
#   '95',  '97',  '85',  '88',  '46',  '87',  '90', '113', '200', '210', '193',
#    '?', '100', '105', '175', '153', '180', '110',  '72',  '86',  '70',  '76',
#   '65',  '69',  '60',  '80',  '54', '208', '155', '112',  '92', '145', '137',
#  '158', '167',  '94', '107', '230',  '49',  '75',  '91', '122',  '67',  '83',
#   '78',  '52',  '61',  '93', '148', '129',  '96',  '71',  '98', '115',  '53',
#   '81',  '79', '120', '152', '102', '108',  '68',  '58', '149',  '89',  '63',
#   '48',  '66', '139', '103', '125', '133', '138', '135', '142',  '77',  '62',
#  '132',  '84',  '64',  '74', '116',  '82']
# Length: 94, dtype: str

# %%
data = data[data.horsepower != '?']

# %%
print('?' in data.horsepower)
# Out:
# False

# %%
data.shape
# Out:
# (392, 8)

# %%
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower          str
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# dtype: object

# %%
data.horsepower = data.horsepower.astype('float')
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# dtype: object

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.025000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %%
data.mpg.describe()
# Out:
# count    392.000000
# mean      23.445918
# std        7.805007
# min        9.000000
# 25%       17.000000
# 50%       22.750000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
sns.distplot(data['mpg'])
# Out:
# <Axes: xlabel='mpg', ylabel='Density'>

# %%
print("Skewness: %f" % data['mpg'].skew())
print("Kurtosis: %f" % data['mpg'].kurt())
# Out:
# Skewness: 0.457092
# Kurtosis: -0.515993

# %%
def scale(a):
    b = (a-a.min())/(a.max()-a.min())
    return b

# %%
data_scale = data.copy()

# %%
data_scale ['displacement'] = scale(data_scale['displacement'])
data_scale['horsepower'] = scale(data_scale['horsepower'])
data_scale ['acceleration'] = scale(data_scale['acceleration'])
data_scale ['weight'] = scale(data_scale['weight'])
data_scale['mpg'] = scale(data_scale['mpg'])

# %%
data_scale.head()
# Out:
#                                 mpg  cylinders  displacement  horsepower  \
# car name
# chevrolet chevelle malibu  0.239362          8      0.617571    0.456522
# buick skylark 320          0.159574          8      0.728682    0.646739
# plymouth satellite         0.239362          8      0.645995    0.565217
# amc rebel sst              0.186170          8      0.609819    0.565217
# ford torino                0.212766          8      0.604651    0.510870
#
#                              weight  acceleration  model year  origin
# car name
# chevrolet chevelle malibu  0.536150      0.238095          70       1
# buick skylark 320          0.589736      0.208333          70       1
# plymouth satellite         0.516870      0.178571          70       1
# amc rebel sst              0.516019      0.238095          70       1
# ford torino                0.520556      0.148810          70       1

# %%
data['Country_code'] = data.origin.replace([1,2,3],['USA','Europe','Japan'])
data_scale['Country_code'] = data.origin.replace([1,2,3],['USA','Europe','Japan'])

# %%
data_scale.head()
# Out:
#                                 mpg  cylinders  displacement  horsepower  \
# car name
# chevrolet chevelle malibu  0.239362          8      0.617571    0.456522
# buick skylark 320          0.159574          8      0.728682    0.646739
# plymouth satellite         0.239362          8      0.645995    0.565217
# amc rebel sst              0.186170          8      0.609819    0.565217
# ford torino                0.212766          8      0.604651    0.510870
#
#                              weight  acceleration  model year  origin  \
# car name
# chevrolet chevelle malibu  0.536150      0.238095          70       1
# buick skylark 320          0.589736      0.208333          70       1
# plymouth satellite         0.516870      0.178571          70       1
# amc rebel sst              0.516019      0.238095          70       1
# ford torino                0.520556      0.148810          70       1
#
#                           Country_code
# car name
# chevrolet chevelle malibu          USA
# buick skylark 320                  USA
# plymouth satellite                 USA
# amc rebel sst                      USA
# ford torino                        USA

# %%
var = 'Country_code'
data_plt = pd.concat([data_scale['mpg'], data_scale[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="mpg", data=data_plt)
fig.axis(ymin=0, ymax=1)
plt.axhline(data_scale.mpg.mean(),color='r',linestyle='dashed',linewidth=2)

# %%
var = 'model year'
data_plt = pd.concat([data_scale['mpg'], data_scale[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="mpg", data=data_plt)
fig.axis(ymin=0, ymax=1)
plt.axhline(data_scale.mpg.mean(),color='r',linestyle='dashed',linewidth=2)

# %%
var = 'cylinders'
data_plt = pd.concat([data_scale['mpg'], data_scale[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="mpg", data=data_plt)
fig.axis(ymin=0, ymax=1)
plt.axhline(data_scale.mpg.mean(),color='r',linestyle='dashed',linewidth=2)

# %%
corrmat = data.select_dtypes(include=[np.number]).corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, square=True)
plt.show()

# %%
factors = ['cylinders','displacement','horsepower','acceleration','weight','mpg']
corrmat = data[factors].corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, square=True);

# %%
#scatterplot
sns.set()
sns.pairplot(data, size = 2.0,hue ='Country_code')
plt.show()

# %%
data.index
# Out:
# Index(['chevrolet chevelle malibu', 'buick skylark 320', 'plymouth satellite',
#        'amc rebel sst', 'ford torino', 'ford galaxie 500', 'chevrolet impala',
#        'plymouth fury iii', 'pontiac catalina', 'amc ambassador dpl',
#        ...
#        'chrysler lebaron medallion', 'ford granada l', 'toyota celica gt',
#        'dodge charger 2.2', 'chevrolet camaro', 'ford mustang gl', 'vw pickup',
#        'dodge rampage', 'ford ranger', 'chevy s-10'],
#       dtype='str', name='car name', length=392)

# %%
data[data.index.str.contains('subaru')].index.str.replace('(.*)', 'subaru dl')
# Out:
# Index(['subaru', 'subaru dl', 'subaru dl', 'subaru'], dtype='str', name='car name')

# %%
data['Company_Name'] = data.index.str.extract('(^.*?)\s', expand=False)

# %%
# Fix naming inconsistencies
data['Company_Name'] = data['Company_Name'].replace(['volkswagen','vokswagen','vw'],'VW')
data['Company_Name'] = data['Company_Name'].replace('maxda','mazda')
data['Company_Name'] = data['Company_Name'].replace('toyouta','toyota')
data['Company_Name'] = data['Company_Name'].replace('mercedes','mercedes-benz')
data['Company_Name'] = data['Company_Name'].replace('nissan','datsun')
data['Company_Name'] = data['Company_Name'].replace('capri','ford')
data['Company_Name'] = data['Company_Name'].replace(['chevroelt','chevy'],'chevrolet')
data['Company_Name'].fillna(value='subaru', inplace=True)
# Out:
# car name
# chevrolet chevelle malibu    chevrolet
# buick skylark 320                buick
# plymouth satellite            plymouth
# amc rebel sst                      amc
# ford torino                       ford
#                                ...
# ford mustang gl                   ford
# vw pickup                           VW
# dodge rampage                    dodge
# ford ranger                       ford
# chevy s-10                   chevrolet
# Name: Company_Name, Length: 392, dtype: str

# %%
var = 'Company_Name'

# Reset indices so they match
mpg_data = data_scale['mpg'].reset_index(drop=True)
company_data = data[var].reset_index(drop=True)

# Now concatenate
data_plt = pd.concat([mpg_data, company_data], axis=1)

f, ax = plt.subplots(figsize=(20,10))
fig = sns.boxplot(x=var, y="mpg", data=data_plt)
fig.set_xticklabels(ax.get_xticklabels(), rotation=30)
plt.axhline(mpg_data.mean(), color='r', linestyle='dashed', linewidth=2)
plt.show()

# %%
data.Company_Name.isnull().any()
# Out:
# np.True_

# %%
var='mpg'
data[data[var]== data[var].min()]
# Out:
#           mpg  cylinders  displacement  horsepower  weight  acceleration  \
# car name
# hi 1200d  9.0          8         304.0       193.0    4732          18.5
#
#           model year  origin Country_code Company_Name
# car name
# hi 1200d          70       1          USA           hi

# %%
data[data[var]== data[var].max()]
# Out:
#             mpg  cylinders  displacement  horsepower  weight  acceleration  \
# car name
# mazda glc  46.6          4          86.0        65.0    2110          17.9
#
#            model year  origin Country_code Company_Name
# car name
# mazda glc          80       3        Japan        mazda

# %%
var='displacement'
data[data[var]== data[var].min()]
# Out:
#            mpg  cylinders  displacement  horsepower  weight  acceleration  \
# car name
# fiat 128  29.0          4          68.0        49.0    1867          19.5
#
#           model year  origin Country_code Company_Name
# car name
# fiat 128          73       2       Europe         fiat

# %%
data[data[var]== data[var].max()]
# Out:
#                            mpg  cylinders  displacement  horsepower  weight  \
# car name
# pontiac catalina          14.0          8         455.0       225.0    4425
# buick estate wagon (sw)   14.0          8         455.0       225.0    3086
# buick electra 225 custom  12.0          8         455.0       225.0    4951
#
#                           acceleration  model year  origin Country_code  \
# car name
# pontiac catalina                  10.0          70       1          USA
# buick estate wagon (sw)           10.0          70       1          USA
# buick electra 225 custom          11.0          73       1          USA
#
#                          Company_Name
# car name
# pontiac catalina              pontiac
# buick estate wagon (sw)         buick
# buick electra 225 custom        buick

# %%
var='horsepower'
data[data[var]== data[var].min()]
# Out:
#                                mpg  cylinders  displacement  horsepower  \
# car name
# volkswagen 1131 deluxe sedan  26.0          4          97.0        46.0
# volkswagen super beetle       26.0          4          97.0        46.0
#
#                               weight  acceleration  model year  origin  \
# car name
# volkswagen 1131 deluxe sedan    1835          20.5          70       2
# volkswagen super beetle         1950          21.0          73       2
#
#                              Country_code Company_Name
# car name
# volkswagen 1131 deluxe sedan       Europe           VW
# volkswagen super beetle            Europe           VW

# %%
data[data[var]== data[var].max()]
# Out:
#                      mpg  cylinders  displacement  horsepower  weight  \
# car name
# pontiac grand prix  16.0          8         400.0       230.0    4278
#
#                     acceleration  model year  origin Country_code Company_Name
# car name
# pontiac grand prix           9.5          73       1          USA      pontiac

# %%
var='weight'
data[data[var]== data[var].min()]
# Out:
#               mpg  cylinders  displacement  horsepower  weight  acceleration  \
# car name
# datsun 1200  35.0          4          72.0        69.0    1613          18.0
#
#              model year  origin Country_code Company_Name
# car name
# datsun 1200          71       3        Japan       datsun

# %%
data[data[var]== data[var].max()]
# Out:
#                       mpg  cylinders  displacement  horsepower  weight  \
# car name
# pontiac safari (sw)  13.0          8         400.0       175.0    5140
#
#                      acceleration  model year  origin Country_code  \
# car name
# pontiac safari (sw)          12.0          71       1          USA
#
#                     Company_Name
# car name
# pontiac safari (sw)      pontiac

# %%
var='acceleration'
data[data[var]== data[var].min()]
# Out:
#                      mpg  cylinders  displacement  horsepower  weight  \
# car name
# plymouth 'cuda 340  14.0          8         340.0       160.0    3609
#
#                     acceleration  model year  origin Country_code Company_Name
# car name
# plymouth 'cuda 340           8.0          70       1          USA     plymouth

# %%
data[data[var]== data[var].max()]
# Out:
#               mpg  cylinders  displacement  horsepower  weight  acceleration  \
# car name
# peugeot 504  27.2          4         141.0        71.0    3190          24.8
#
#              model year  origin Country_code Company_Name
# car name
# peugeot 504          79       2       Europe      peugeot

# %%
var = 'horsepower'
plot = sns.lmplot(x=var, y='mpg', data=data, hue='Country_code')
plot.set(ylim=(0,50))

# %%
var = 'displacement'
plot = sns.lmplot(x=var, y='mpg', data=data, hue='Country_code')
plot.set(ylim=(0,50))

# %%
var = 'weight'
plot = sns.lmplot(x=var,y='mpg',data=data,hue='Country_code')
plot.set(ylim = (0,50))

# %%
var = 'acceleration'
plot = sns.lmplot(x=var,y='mpg',data=data,hue='Country_code')
plot.set(ylim = (0,50))

# %%
data['Power_to_weight'] = ((data.horsepower*0.7457)/data.weight)

# %%
data.sort_values(by='Power_to_weight',ascending=False ).head()
# Out:
#                           mpg  cylinders  displacement  horsepower  weight  \
# car name
# buick estate wagon (sw)  14.0          8         455.0       225.0    3086
# pontiac grand prix       16.0          8         400.0       230.0    4278
# pontiac catalina         14.0          8         455.0       225.0    4425
# bmw 2002                 26.0          4         121.0       113.0    2234
# chevrolet impala         14.0          8         454.0       220.0    4354
#
#                          acceleration  model year  origin Country_code  \
# car name
# buick estate wagon (sw)          10.0          70       1          USA
# pontiac grand prix                9.5          73       1          USA
# pontiac catalina                 10.0          70       1          USA
# bmw 2002                         12.5          70       2       Europe
# chevrolet impala                  9.0          70       1          USA
#
#                         Company_Name  Power_to_weight
# car name
# buick estate wagon (sw)        buick         0.054369
# pontiac grand prix           pontiac         0.040091
# pontiac catalina             pontiac         0.037917
# bmw 2002                         bmw         0.037719
# chevrolet impala           chevrolet         0.037679

# %%
data.head()
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# car name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
#
#                            acceleration  model year  origin Country_code  \
# car name
# chevrolet chevelle malibu          12.0          70       1          USA
# buick skylark 320                  11.5          70       1          USA
# plymouth satellite                 11.0          70       1          USA
# amc rebel sst                      12.0          70       1          USA
# ford torino                        10.5          70       1          USA
#
#                           Company_Name  Power_to_weight
# car name
# chevrolet chevelle malibu    chevrolet         0.027666
# buick skylark 320                buick         0.033317
# plymouth satellite            plymouth         0.032554
# amc rebel sst                      amc         0.032582
# ford torino                       ford         0.030269

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold

# %%
factors = ['cylinders','displacement','horsepower','acceleration','weight','origin','model year']
X = pd.DataFrame(data[factors].copy())
y = data['mpg'].copy()

# %%
X = StandardScaler().fit_transform(X)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size = 0.33,random_state=324)
X_train.shape[0] == y_train.shape[0]
# Out:
# True

# %%
regressor = LinearRegression()

# %%
regressor.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'positive': False,
#  'tol': 1e-06}

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predicted = regressor.predict(X_test)

# %%
rmse = sqrt(mean_squared_error(y_true=y_test,y_pred=y_predicted))
rmse
# Out:
# 3.4867296149015616

# %%
gb_regressor = GradientBoostingRegressor(n_estimators=4000)
gb_regressor.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(n_estimators=4000)

# %%
gb_regressor.get_params()
# Out:
# {'alpha': 0.9,
#  'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'squared_error',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 4000,
#  'n_iter_no_change': None,
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
y_predicted_gbr = gb_regressor.predict(X_test)

# %%
rmse_bgr = sqrt(mean_squared_error(y_true=y_test,y_pred=y_predicted_gbr))
rmse_bgr
# Out:
# 2.7009569773235858

# %%
fi= pd.Series(gb_regressor.feature_importances_,index=factors)
fi.plot.barh()
# Out:
# <Axes: >

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
pca.fit(data[factors])
# Out:
# PCA(n_components=2)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.99756151, 0.0020628 ])

# %%
pca1 = pca.components_[0]
pca2 = pca.components_[1]

# %%
transformed_data = pca.transform(data[factors])

# %%
pc1 = transformed_data[:,0]
pc2 = transformed_data[:,1]

# %%
plt.scatter(pc1,pc2)

# %%
c = pca.inverse_transform(transformed_data[(transformed_data[:,0]>0 )& (transformed_data[:,1]>250)])

# %%
factors
# Out:
# ['cylinders',
#  'displacement',
#  'horsepower',
#  'acceleration',
#  'weight',
#  'origin',
#  'model year']

# %%
c
# Out:
# array([[9.32016159e+00, 4.65727261e+02, 1.90441442e+02, 5.95699243e+00,
#         3.08611199e+03, 6.23550659e-01, 6.93571097e+01]])

# %%
data[(data['model year'] == 70 )&( data.displacement>400)]
# Out:
#                           mpg  cylinders  displacement  horsepower  weight  \
# car name
# ford galaxie 500         15.0          8         429.0       198.0    4341
# chevrolet impala         14.0          8         454.0       220.0    4354
# plymouth fury iii        14.0          8         440.0       215.0    4312
# pontiac catalina         14.0          8         455.0       225.0    4425
# buick estate wagon (sw)  14.0          8         455.0       225.0    3086
#
#                          acceleration  model year  origin Country_code  \
# car name
# ford galaxie 500                 10.0          70       1          USA
# chevrolet impala                  9.0          70       1          USA
# plymouth fury iii                 8.5          70       1          USA
# pontiac catalina                 10.0          70       1          USA
# buick estate wagon (sw)          10.0          70       1          USA
#
#                         Company_Name  Power_to_weight
# car name
# ford galaxie 500                ford         0.034013
# chevrolet impala           chevrolet         0.037679
# plymouth fury iii           plymouth         0.037181
# pontiac catalina             pontiac         0.037917
# buick estate wagon (sw)        buick         0.054369

# %%
cv_sets = KFold(n_splits=5, shuffle=True, random_state=100)  # Reduced from 10 to 5

params = {
    'n_estimators': [40, 50, 60],        # Just 3 values instead of 21
    'max_depth': [3, 5, 7],              # Just 3 values instead of 9
    'learning_rate': [0.1, 0.2, 0.3]     # Keep as is
}

grid = GridSearchCV(gb_regressor, params, cv=cv_sets, n_jobs=4, verbose=2)
grid = grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=60; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=50; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=50; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=60; total time=   0.2s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=60; total time=   0.2s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=60; total time=   0.2s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=40; total time=   0.2s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=50; total time=   0.2s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=60; total time=   0.2s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=50; total time=   0.0s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=50; total time=   0.2s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=60; total time=   0.2s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=60; total time=   0.2s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=50; total time=   0.2s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=60; total time=   0.2s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=60; total time=   0.1s

# %%
grid = grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=60; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=60; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=60; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=50; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=50; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=50; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=60; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=50; total time=   0.3s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=50; total time=   0.0s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=60; total time=   0.0s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=60; total time=   0.2s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=60; total time=   0.2s
# [CV] END ....learning_rate=0.3, max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=5, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=40; total time=   0.0s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=40; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=50; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=60; total time=   0.1s
# [CV] END ....learning_rate=0.3, max_depth=7, n_estimators=60; total time=   0.1s

# %%
grid.best_estimator_
# Out:
# GradientBoostingRegressor(n_estimators=60)

# %%
gb_regressor_t = grid.best_estimator_

# %%
gb_regressor_t.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(n_estimators=60)

# %%
y_predicted_gbr_t = gb_regressor_t.predict(X_test)

# %%
rmse = sqrt(mean_squared_error(y_true=y_test,y_pred=y_predicted_gbr_t))
rmse
# Out:
# 2.6393926764719464

# %%
data.duplicated().any()
# Out:
# np.False_
